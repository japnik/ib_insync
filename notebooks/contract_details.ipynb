# %% [markdown]
# Contract details
# -------------------

# %%
from ib_insync import *
util.startLoop()

import logging
# util.logToConsole(logging.DEBUG)

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=11)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=11>

# %%
amd = Stock('AMC', 'SMART', 'USD')
ib.qualifyContracts(amd)
amd
# Out:
# Stock(conId=140070600, symbol='AMC', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='AMC', tradingClass='AMC')

# %%
amd = Stock('AMC', 'SMART', 'USD')
cds = ib.reqContractDetails(amd)
len(cds)
# Out:
# 1

# %%
import pandas as pd

# %%
d = [{"a" :1}, {"a": 2, "b":4}]
pd.DataFrame(d)
# Out:
#    a    b
# 0  1  NaN
# 1  2  4.0

# %%
cds
# Out:
# [ContractDetails(contract=Contract(secType='STK', conId=4109657, symbol='AMC', exchange='SMART', primaryExchange='ASX', currency='AUD', localSymbol='AMC', tradingClass='AMC'), marketName='AMC', minTick=0.001, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALGOLTH,ALLOC,AVGCOST,BASKET,BENCHPX,CASHQTY,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,REL,RELPCTOFS,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='SMART,ASX,ASXCEN', priceMagnifier=1, underConId=0, longName='AMCOR PLC-CDI', contractMonth='', industry='Industrial', category='Packaging&Containers', subcategory='Containers-Paper/Plastic', timeZoneId='Australia/NSW', tradingHours='20210607:0959-20210607:1612;20210608:0959-20210608:1612;20210609:0959-20210609:1612;20210610:0959-20210610:1612;20210611:0959-20210611:1612', liquidHours='20210607:0959-20210607:1612;20210608:0959-20210608:1612;20210609:0959-20210609:1612;20210610:0959-20210610:1612;20210611:0959-20210611:1612', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=17, underSymbol='', underSecType='', marketRuleIds='614,614,614', secIdList=[TagValue(tag='ISIN', value='AU000000AMC4')], realExpirationDate='', lastTradeTime='', stockType='CDI', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='STK', conId=80702338, symbol='AMC', exchange='SMART', primaryExchange='FWB', currency='EUR', localSymbol='AMC', tradingClass='XETRA'), marketName='XETRA', minTick=0.0001, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGOLTH,ALLOC,AVGCOST,BASKET,BENCHPX,CASHQTY,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,IOC,LIT,LMT,LOC,LTH,MIT,MKT,MKT2BBO,MOC,MTL,NGCOMB,NODARK,NONALGO,OCA,OPG,PEGBENCH,REL,RELPCTOFS,SIZECHK,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='SMART,FWB,GETTEX', priceMagnifier=1, underConId=0, longName='ALBEMARLE CORP', contractMonth='', industry='Basic Materials', category='Chemicals', subcategory='Chemicals-Specialty', timeZoneId='MET', tradingHours='20210607:0800-20210607:2000;20210608:0800-20210608:2000;20210609:0800-20210609:2000;20210610:0800-20210610:2000;20210611:0800-20210611:2000', liquidHours='20210607:0900-20210607:1730;20210608:0900-20210608:1730;20210609:0900-20210609:1730;20210610:0900-20210610:1730;20210611:0900-20210611:1730', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=6, underSymbol='', underSecType='', marketRuleIds='1873,1873,1873', secIdList=[TagValue(tag='ISIN', value='US0126531013')], realExpirationDate='', lastTradeTime='', stockType='COMMON', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='STK', conId=90207746, symbol='AMC', exchange='SMART', primaryExchange='LSE', currency='GBP', localSymbol='AMC', tradingClass='AMSM'), marketName='AMSM', minTick=1e-06, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGOLTH,ALLOC,AUC,AVGCOST,BASKET,BENCHPX,CASHQTY,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,IOC,LIT,LMT,LOC,LTH,MIT,MKT,MKT2BBO,MOC,MTL,NGCOMB,NODARK,NONALGO,OCA,OPG,PEGBENCH,SIZECHK,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='SMART,LSE', priceMagnifier=100, underConId=0, longName='AMUR MINERALS CORP', contractMonth='', industry='Basic Materials', category='Mining', subcategory='Diversified Minerals', timeZoneId='GB-Eire', tradingHours='20210607:0800-20210607:1650;20210608:0800-20210608:1650;20210609:0800-20210609:1650;20210610:0800-20210610:1650;20210611:0800-20210611:1650', liquidHours='20210607:0800-20210607:1630;20210608:0800-20210608:1630;20210609:0800-20210609:1630;20210610:0800-20210610:1630;20210611:0800-20210611:1630', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=3, underSymbol='', underSecType='', marketRuleIds='1916,1916', secIdList=[TagValue(tag='ISIN', value='VGG042401007')], realExpirationDate='', lastTradeTime='', stockType='COMMON', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='STK', conId=140070600, symbol='AMC', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='AMC', tradingClass='AMC'), marketName='AMC', minTick=0.0001, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,BENCHPX,CASHQTY,COND,CONDORDER,DARKONLY,DARKPOLL,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,DUR,GAT,GTC,GTD,GTT,HID,IBKRATS,ICE,IMB,IOC,LIT,LMT,LOC,MIDPX,MIT,MKT,MOC,MTL,NGCOMB,NODARK,NONALGO,OCA,OPG,OPGREROUT,PEGBENCH,POSTONLY,PREOPGRTH,PRICECHK,REL,RELPCTOFS,RPI,RTH,RTHIGNOPG,SCALE,SCALEODD,SCALERST,SIZECHK,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,SWEEP,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='SMART,AMEX,NYSE,CBOE,PHLX,ISE,CHX,ARCA,ISLAND,DRCTEDGE,BEX,BATS,EDGEA,CSFBALGO,JEFFALGO,BYX,IEX,EDGX,FOXRIVER,PEARL,NYSENAT,LTSE,MEMX,PSX', priceMagnifier=1, underConId=0, longName='AMC ENTERTAINMENT HLDS-CL A', contractMonth='', industry='Consumer, Cyclical', category='Entertainment', subcategory='Theaters', timeZoneId='US/Eastern', tradingHours='20210606:CLOSED;20210607:0400-20210607:2000;20210608:0400-20210608:2000;20210609:0400-20210609:2000;20210610:0400-20210610:2000;20210611:0400-20210611:2000', liquidHours='20210606:CLOSED;20210607:0930-20210607:1600;20210608:0930-20210608:1600;20210609:0930-20210609:1600;20210610:0930-20210610:1600;20210611:0930-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=100, aggGroup=1, underSymbol='', underSecType='', marketRuleIds='557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557', secIdList=[TagValue(tag='ISIN', value='US00165C1045')], realExpirationDate='', lastTradeTime='', stockType='COMMON', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='STK', conId=376830679, symbol='AMC', exchange='SMART', primaryExchange='VENTURE', currency='CAD', localSymbol='AMC', tradingClass='AMC'), marketName='AMC', minTick=0.005, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALLOC,AVGCOST,BASKET,BENCHPX,CASHQTY,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,LARGE,LIT,LMT,LOC,MINLOT,MIT,MKT,MOC,MTL,NGCOMB,NONALGO,OCA,OPG,PEGBENCH,PEGMID,REL,RELPCTOFS,RTH,SIZECHK,SMARTSTGA,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='SMART,VENTURE', priceMagnifier=1, underConId=0, longName='ARIZONA METALS CORP', contractMonth='', industry='Basic Materials', category='Mining', subcategory='Gold Mining', timeZoneId='US/Eastern', tradingHours='20210606:CLOSED;20210607:0800-20210607:1700;20210608:0800-20210608:1700;20210609:0800-20210609:1700;20210610:0800-20210610:1700;20210611:0800-20210611:1700', liquidHours='20210606:CLOSED;20210607:0930-20210607:1600;20210608:0930-20210608:1600;20210609:0930-20210609:1600;20210610:0930-20210610:1600;20210611:0930-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=11, underSymbol='', underSecType='', marketRuleIds='357,357', secIdList=[TagValue(tag='ISIN', value='CA0405181029')], realExpirationDate='', lastTradeTime='', stockType='COMMON', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes='')]

# %%
eur = Forex('EURUSD')
ib.qualifyContracts(eur)
eur
# Out:
# Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD')

# %%
es = Future('ES')


cds = ib.reqContractDetails(es)
len(cds)
# ib.qualifyContracts(es)
# es
# Out:
# 24

# %%
cds
# Out:
# [ContractDetails(contract=Contract(secType='FUT', conId=412889032, symbol='ES', lastTradeDateOrContractMonth='20210618', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESM1', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202106', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20210618', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=412889032, symbol='ES', lastTradeDateOrContractMonth='20210618', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESM1', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202106', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20210618', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=428520022, symbol='ES', lastTradeDateOrContractMonth='20210917', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESU1', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202109', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20210917', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=428520022, symbol='ES', lastTradeDateOrContractMonth='20210917', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESU1', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202109', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20210917', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=446091461, symbol='ES', lastTradeDateOrContractMonth='20211217', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESZ1', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202112', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20211217', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=446091461, symbol='ES', lastTradeDateOrContractMonth='20211217', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESZ1', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202112', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20211217', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=461318816, symbol='ES', lastTradeDateOrContractMonth='20220317', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESH2', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202203', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20220318', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=461318816, symbol='ES', lastTradeDateOrContractMonth='20220317', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESH2', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202203', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20220318', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=477836957, symbol='ES', lastTradeDateOrContractMonth='20220616', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESM2', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202206', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20220617', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=477836957, symbol='ES', lastTradeDateOrContractMonth='20220616', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESM2', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202206', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20220617', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512551, symbol='ES', lastTradeDateOrContractMonth='20221215', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESZ2', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202212', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20221216', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512551, symbol='ES', lastTradeDateOrContractMonth='20221215', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESZ2', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202212', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20221216', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512552, symbol='ES', lastTradeDateOrContractMonth='20231214', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESZ3', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202312', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20231215', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512552, symbol='ES', lastTradeDateOrContractMonth='20231214', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESZ3', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202312', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20231215', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512557, symbol='ES', lastTradeDateOrContractMonth='20241219', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESZ4', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202412', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20241220', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512557, symbol='ES', lastTradeDateOrContractMonth='20241219', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESZ4', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202412', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20241220', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512563, symbol='ES', lastTradeDateOrContractMonth='20251218', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESZ5', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202512', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20251219', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512563, symbol='ES', lastTradeDateOrContractMonth='20251218', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESZ5', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202512', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20251219', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512566, symbol='ES', lastTradeDateOrContractMonth='20220915', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESU2', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202209', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20220916', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512566, symbol='ES', lastTradeDateOrContractMonth='20220915', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESU2', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202209', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20220916', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512569, symbol='ES', lastTradeDateOrContractMonth='20230615', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESM3', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202306', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20230616', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512569, symbol='ES', lastTradeDateOrContractMonth='20230615', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESM3', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202306', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20230616', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512572, symbol='ES', lastTradeDateOrContractMonth='20230316', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESH3', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MKTPROT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,RFQ,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,STPPROT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202303', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours='20210606:CLOSED;20210607:0830-20210607:1515;20210607:1530-20210607:1600;20210608:0830-20210608:1515;20210608:1530-20210608:1600;20210609:0830-20210609:1515;20210609:1530-20210609:1600;20210610:0830-20210610:1515;20210610:1530-20210610:1600;20210611:0830-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20230317', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes=''),
#  ContractDetails(contract=Contract(secType='FUT', conId=495512572, symbol='ES', lastTradeDateOrContractMonth='20230316', multiplier='50', exchange='QBALGO', currency='USD', localSymbol='ESH3', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='AD,ALERT,ALGO,ALLOC,AVGCOST,BASKET,BENCHPX,DAY,DEACT,DEACTDIS,LMT,MKT,NGCOMB,OPENCLOSE,WHATIF', validExchanges='GLOBEX,QBALGO', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='202303', industry='', category='', subcategory='', timeZoneId='US/Central', tradingHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', liquidHours=';20210606:1700-20210607:1515;20210607:1530-20210607:1600;20210607:1700-20210608:1515;20210608:1530-20210608:1600;20210608:1700-20210609:1515;20210609:1530-20210609:1600;20210609:1700-20210610:1515;20210610:1530-20210610:1600;20210610:1700-20210611:1515;20210611:1530-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=1, aggGroup=2147483647, underSymbol='ES', underSecType='IND', marketRuleIds='67,67', secIdList=[], realExpirationDate='20230317', lastTradeTime='08:30', stockType='', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes='')]

# %% [markdown]
# Suppose we want to find the contract details for AMD stock.
# Let's create a stock object and request the details for it:

# %%
amd = Stock('AMC')

cds = ib.reqContractDetails(amd)

len(cds)
# Out:
# 35

# %% [markdown]
# We get a long list of contract details. Lets print the first one:

# %%
cds[0]
# Out:
# ContractDetails(contract=Contract(secType='STK', conId=140070600, symbol='AMC', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='AMC', tradingClass='AMC'), marketName='AMC', minTick=0.0001, orderTypes='ACTIVETIM,AD,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,BENCHPX,CASHQTY,COND,CONDORDER,DARKONLY,DARKPOLL,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,DUR,GAT,GTC,GTD,GTT,HID,IBKRATS,ICE,IMB,IOC,LIT,LMT,LOC,MIDPX,MIT,MKT,MOC,MTL,NGCOMB,NODARK,NONALGO,OCA,OPG,OPGREROUT,PEGBENCH,POSTONLY,PREOPGRTH,PRICECHK,REL,RELPCTOFS,RPI,RTH,RTHIGNOPG,SCALE,SCALEODD,SCALERST,SIZECHK,SNAPMID,SNAPMKT,SNAPREL,STP,STPLMT,SWEEP,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='SMART,AMEX,NYSE,CBOE,PHLX,ISE,CHX,ARCA,ISLAND,DRCTEDGE,BEX,BATS,EDGEA,CSFBALGO,JEFFALGO,BYX,IEX,EDGX,FOXRIVER,PEARL,NYSENAT,LTSE,MEMX,PSX', priceMagnifier=1, underConId=0, longName='AMC ENTERTAINMENT HLDS-CL A', contractMonth='', industry='Consumer, Cyclical', category='Entertainment', subcategory='Theaters', timeZoneId='US/Eastern', tradingHours='20210606:CLOSED;20210607:0400-20210607:2000;20210608:0400-20210608:2000;20210609:0400-20210609:2000;20210610:0400-20210610:2000;20210611:0400-20210611:2000', liquidHours='20210606:CLOSED;20210607:0930-20210607:1600;20210608:0930-20210608:1600;20210609:0930-20210609:1600;20210610:0930-20210610:1600;20210611:0930-20210611:1600', evRule='', evMultiplier=0, mdSizeMultiplier=100, aggGroup=1, underSymbol='', underSecType='', marketRuleIds='557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557,557', secIdList=[TagValue(tag='ISIN', value='US00165C1045')], realExpirationDate='', lastTradeTime='', stockType='COMMON', cusip='', ratings='', descAppend='', bondType='', couponType='', callable=False, putable=False, coupon=0, convertible=False, maturity='', issueDate='', nextOptionDate='', nextOptionType='', nextOptionPartial=False, notes='')

# %% [markdown]
# The contract itself is in the 'contract' property of the contract details. Lets make a list of contracts and look at the first:

# %%
contracts = [cd.contract for cd in cds]

contracts[0]
# Out:
# Contract(secType='STK', conId=140070600, symbol='AMC', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='AMC', tradingClass='AMC')

# %% [markdown]
# To better spot the difference between all the contracts it's handy to convert to a DataFrame. There is a utility function to do that:

# %%
util.df(contracts)
# Out:
#    secType      conId symbol lastTradeDateOrContractMonth  strike right  \
# 0      STK  140070600    AMC                                  0.0
# 1      STK  140070600    AMC                                  0.0
# 2      STK    4109657    AMC                                  0.0
# 3      STK    4109657    AMC                                  0.0
# 4      STK    4109657    AMC                                  0.0
# 5      STK   80702338    AMC                                  0.0
# 6      STK   80702338    AMC                                  0.0
# 7      STK   90207746    AMC                                  0.0
# 8      STK  140070600    AMC                                  0.0
# 9      STK  140070600    AMC                                  0.0
# 10     STK  140070600    AMC                                  0.0
# 11     STK  140070600    AMC                                  0.0
# 12     STK  140070600    AMC                                  0.0
# 13     STK  140070600    AMC                                  0.0
# 14     STK  140070600    AMC                                  0.0
# 15     STK  140070600    AMC                                  0.0
# 16     STK  140070600    AMC                                  0.0
# 17     STK  140070600    AMC                                  0.0
# 18     STK  140070600    AMC                                  0.0
# 19     STK  140070600    AMC                                  0.0
# 20     STK  140070600    AMC                                  0.0
# 21     STK  140070600    AMC                                  0.0
# 22     STK  140070600    AMC                                  0.0
# 23     STK  140070600    AMC                                  0.0
# 24     STK  140070600    AMC                                  0.0
# 25     STK  140070600    AMC                                  0.0
# 26     STK  140070600    AMC                                  0.0
# 27     STK  140070600    AMC                                  0.0
# 28     STK  140070600    AMC                                  0.0
# 29     STK  140070600    AMC                                  0.0
# 30     STK  268960208    AMC                                  0.0
# 31     STK  376830679    AMC                                  0.0
# 32     STK   80702338    AMC                                  0.0
# 33     STK   90207746    AMC                                  0.0
# 34     STK  376830679    AMC                                  0.0
#
#    multiplier  exchange primaryExchange currency localSymbol tradingClass  \
# 0                 SMART            NYSE      USD         AMC          AMC
# 1                ISLAND            NYSE      USD         AMC          AMC
# 2                 SMART             ASX      AUD         AMC          AMC
# 3                   ASX             ASX      AUD         AMC          AMC
# 4                ASXCEN             ASX      AUD         AMC          AMC
# 5                   FWB             FWB      EUR         AMC        XETRA
# 6                GETTEX             FWB      EUR         AMC        XETRA
# 7                   LSE             LSE      GBP         AMC         AMSM
# 8                  AMEX            NYSE      USD         AMC          AMC
# 9                  NYSE            NYSE      USD         AMC          AMC
# 10                 CBOE            NYSE      USD         AMC          AMC
# 11                 PHLX            NYSE      USD         AMC          AMC
# 12                  ISE            NYSE      USD         AMC          AMC
# 13                  CHX            NYSE      USD         AMC          AMC
# 14                 ARCA            NYSE      USD         AMC          AMC
# 15             DRCTEDGE            NYSE      USD         AMC          AMC
# 16                  BEX            NYSE      USD         AMC          AMC
# 17                 BATS            NYSE      USD         AMC          AMC
# 18                EDGEA            NYSE      USD         AMC          AMC
# 19             CSFBALGO            NYSE      USD         AMC          AMC
# 20             JEFFALGO            NYSE      USD         AMC          AMC
# 21                  BYX            NYSE      USD         AMC          AMC
# 22                  IEX            NYSE      USD         AMC          AMC
# 23                 EDGX            NYSE      USD         AMC          AMC
# 24             FOXRIVER            NYSE      USD         AMC          AMC
# 25                PEARL            NYSE      USD         AMC          AMC
# 26              NYSENAT            NYSE      USD         AMC          AMC
# 27                 LTSE            NYSE      USD         AMC          AMC
# 28                 MEMX            NYSE      USD         AMC          AMC
# 29                  PSX            NYSE      USD         AMC          AMC
# 30                  WSE             WSE      PLN         AMC          AMC
# 31              VENTURE         VENTURE      CAD         AMC          AMC
# 32                SMART             FWB      EUR         AMC        XETRA
# 33                SMART             LSE      GBP         AMC         AMSM
# 34                SMART         VENTURE      CAD         AMC          AMC
#
#     includeExpired secIdType secId comboLegsDescrip comboLegs  \
# 0            False                                         []
# 1            False                                         []
# 2            False                                         []
# 3            False                                         []
# 4            False                                         []
# 5            False                                         []
# 6            False                                         []
# 7            False                                         []
# 8            False                                         []
# 9            False                                         []
# 10           False                                         []
# 11           False                                         []
# 12           False                                         []
# 13           False                                         []
# 14           False                                         []
# 15           False                                         []
# 16           False                                         []
# 17           False                                         []
# 18           False                                         []
# 19           False                                         []
# 20           False                                         []
# 21           False                                         []
# 22           False                                         []
# 23           False                                         []
# 24           False                                         []
# 25           False                                         []
# 26           False                                         []
# 27           False                                         []
# 28           False                                         []
# 29           False                                         []
# 30           False                                         []
# 31           False                                         []
# 32           False                                         []
# 33           False                                         []
# 34           False                                         []
#
#    deltaNeutralContract
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# 10                 None
# 11                 None
# 12                 None
# 13                 None
# 14                 None
# 15                 None
# 16                 None
# 17                 None
# 18                 None
# 19                 None
# 20                 None
# 21                 None
# 22                 None
# 23                 None
# 24                 None
# 25                 None
# 26                 None
# 27                 None
# 28                 None
# 29                 None
# 30                 None
# 31                 None
# 32                 None
# 33                 None
# 34                 None

# %% [markdown]
# We can see from this that AMD trades in different currencies on different exchanges.
# Suppose we want the one in USD on the SMART exchange. The AMD contract is adjusted to
# reflect that and becomes unique:

# %%
amd = Stock('AMC', 'SMART', 'USD')

assert len(ib.reqContractDetails(amd)) == 1

# %% [markdown]
# Lets try the same for Intel:

# %%
intc = Stock('INTC', 'SMART', 'USD')

assert len(ib.reqContractDetails(intc)) == 1

# %% [markdown]
# Let's try a non-existing contract:

# %%
xxx = Stock('XXX', 'SMART', 'USD')

assert len(ib.reqContractDetails(xxx)) == 0
# Out:
# Error 200, reqId 8: No security definition has been found for the request, contract: Stock(symbol='XXX', exchange='SMART', currency='USD')

# %% [markdown]
# or a Forex contract

# %%
eurusd = Forex('EURUSD')

assert len(ib.reqContractDetails(eurusd)) == 1

# %% [markdown]
# With the ``qualifyContracts`` method the extra information that is send back
# from the contract details request is used to fill in the original contracts.
#
# Lets do that with ``amd`` and compare before and aftwards:

# %%
amd
# Out:
# Stock(symbol='AMC', exchange='SMART', currency='USD')

# %%
ib.qualifyContracts(amd)
amd
# Out:
# Stock(conId=140070600, symbol='AMC', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='AMC', tradingClass='AMC')

# %% [markdown]
# **TIP:** When printing a contract, the output can be copy-pasted and it will be valid Python code.
#
# The ``conId`` that is returned can by itself be used to uniquely specify a contract:

# %%
contract_4391 = Contract(conId=4391)

ib.qualifyContracts(contract_4391)

assert contract_4391 == amd
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-ff3dfdb3a1cb> in <module>
#       3 ib.qualifyContracts(contract_4391)
#       4
# ----> 5 assert contract_4391 == amd
#
# AssertionError:

# %% [markdown]
# A whole bunch of contracts can be qualified at the same time. A list of all the successfull ones is returned:

# %%
qualContracts = ib.qualifyContracts(amd, intc, xxx, eurusd)

assert intc in qualContracts
assert xxx not in qualContracts
# Out:
# Error 200, reqId 14: No security definition has been found for the request, contract: Stock(symbol='XXX', exchange='SMART', currency='USD')
# Unknown contract: Stock(symbol='XXX', exchange='SMART', currency='USD')

# %% [markdown]
# There is also an API function to request stocks (only stocks) that match a pattern:

# %%
matches = ib.reqMatchingSymbols('intc')
matchContracts = [m.contract for m in matches]

matches
# Out:
# [ContractDescription(contract=Contract(secType='IND', conId=291241822, symbol='NY2LINTC', primaryExchange='NYSE', currency='USD'), derivativeSecTypes=[]),
#  ContractDescription(contract=Contract(secType='IND', conId=86792745, symbol='INTSY', primaryExchange='NASDAQ', currency='USD'), derivativeSecTypes=[]),
#  ContractDescription(contract=Contract(secType='STK', conId=270639, symbol='INTC', primaryExchange='NASDAQ.NMS', currency='USD'), derivativeSecTypes=['CFD', 'OPT', 'IOPT', 'WAR', 'BAG']),
#  ContractDescription(contract=Contract(secType='STK', conId=12178234, symbol='INTC', primaryExchange='EBS', currency='CHF'), derivativeSecTypes=[]),
#  ContractDescription(contract=Contract(secType='STK', conId=38709539, symbol='INTC', primaryExchange='MEXI', currency='MXN'), derivativeSecTypes=[]),
#  ContractDescription(contract=Contract(secType='STK', conId=11463493, symbol='INTCUSD', primaryExchange='EBS', currency='USD'), derivativeSecTypes=[]),
#  ContractDescription(contract=Contract(secType='STK', conId=427045002, symbol='300677', primaryExchange='CHINEXT', currency='CNH'), derivativeSecTypes=[])]

# %%
assert intc in matchContracts

# %%
ib.disconnect()
